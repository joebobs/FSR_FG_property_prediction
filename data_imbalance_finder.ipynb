# %%
config_mod_list = {}

config = {}
config['smiles_col'] = ['smiles']  #list
config['target_col'] = None #list
config['file_name'] = 'freesolv.csv'
config['dataset_type'] = 'regression'
config['metrics']      = ['rmse', 'mae']
config['metric']       = 'rmse'
config['minimize_score'] = True
config['features_filename'] = 'features/freesolv_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['smiles']  #list
config['target_col'] = None #list
config['file_name'] = 'delaney.csv'
config['dataset_type'] = 'regression'
config['metrics']      = ['rmse', 'mae']
config['metric']       = 'rmse'
config['minimize_score'] = True
config['features_filename'] = 'features/delaney_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['smiles']  #list
config['target_col'] = ['lipo'] #list
config['file_name'] = 'lipo.csv'
config['dataset_type'] = 'regression'
config['metrics']      = ['rmse', 'mae']
config['metric']       = 'rmse'
config['minimize_score'] = True
config['features_filename'] = 'features/lipo_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['mol']  #list
config['target_col'] = ['Class']    #list
config['file_name'] = 'bace.csv'
config['dataset_type'] = 'classification'
config['metrics']      = ['auc', 'prc-auc']
config['metric']       = 'auc'
config['minimize_score'] = False
config['features_filename'] = 'features/bace_rdkit.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['Peptide_smiles']  #list
config['target_col'] = ['cleavage'] #list
config['file_name'] = 'impensData_with_smiles.csv'
config['dataset_type'] = 'classification'
config['metrics']      = ['auc', 'prc-auc']
config['metric']       = 'auc'
config['minimize_score'] = False
config['features_filename'] = 'features/impensData_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['smiles']  #list
config['target_col'] = ["p_np"] #list
config['file_name'] = 'bbbp_ch.csv'
config['dataset_type'] = 'classification'
config['metrics']      = ['auc', 'prc-auc']
config['metric']       = 'auc'
config['minimize_score'] = False
config['features_filename'] = 'features/bbbp_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['smiles']  #list
config['target_col'] = None #list
config['file_name'] = 'tox21_ch.csv'
config['dataset_type'] = 'classification'
config['metrics']      = ['auc', 'prc-auc']
config['metric']       = 'auc'
config['minimize_score'] = False
config['features_filename'] = 'features/tox21_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['smiles']  #list
config['target_col'] = None #list
config['file_name'] = 'ecoli_inhibition.csv'
config['dataset_type'] = 'classification'
config['metrics']      = ['auc', 'prc-auc']
config['metric']       = 'auc'
config['minimize_score'] = False
config['features_filename'] = 'features/ecoli_inhibition_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['Peptide_smiles']  #list
config['target_col'] = ['cleavage'] #list
config['file_name'] = 'impensData_with_smiles.csv'
config['dataset_type'] = 'classification'
config['metrics']      = ['auc', 'prc-auc']
config['metric']       = 'auc'
config['minimize_score'] = False
config['features_filename'] = 'features/impensData_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['Peptide_smiles']  #list
config['target_col'] = ['cleavage'] #list
config['file_name'] = '746Data_with_smiles.csv'
config['dataset_type'] = 'classification'
config['metrics']      = ['auc', 'prc-auc']
config['metric']       = 'auc'
config['minimize_score'] = False
config['features_filename'] = 'features/746Data_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['Peptide_smiles']  #list
config['target_col'] = ['cleavage'] #list
config['file_name'] = '1625Data_with_smiles.csv'
config['dataset_type'] = 'classification'
config['metrics']      = ['auc', 'prc-auc']
config['metric']       = 'auc'
config['minimize_score'] = False
config['features_filename'] = 'features/1625Data_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['Peptide_smiles']  #list
config['target_col'] = ['cleavage'] #list
config['file_name'] = 'schillingData_with_smiles.csv'
config['dataset_type'] = 'classification'
config['metrics']      = ['auc', 'prc-auc']
config['metric']       = 'auc'
config['minimize_score'] = False
config['features_filename'] = 'features/schillingData_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['SMILES']  #list
config['target_col'] = None #list
config['file_name'] = 'mproxchem_ch.csv'
config['dataset_type'] = 'classification'
config['metrics']      = ['auc', 'prc-auc']
config['metric']       = 'auc'
config['minimize_score'] = False
config['features_filename'] = 'features/mproxchem_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['smiles']  #list
config['target_col'] = None #list
config['file_name'] = 'clintox.csv'
config['dataset_type'] = 'classification'
config['metrics']      = ['auc', 'prc-auc']
config['metric']       = 'auc'
config['minimize_score'] = False
config['features_filename'] = 'features/clintox_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['smiles']  #list
config['target_col'] = None #list
config['file_name'] = 'sider.csv'
config['dataset_type'] = 'classification'
config['metrics']      = ['auc', 'prc-auc']
config['metric']       = 'auc'
config['minimize_score'] = False
config['features_filename'] = 'features/sider_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['smiles']  #list
config['target_col'] = None #list
config['file_name'] = 'tox21_ch.csv'
config['dataset_type'] = 'classification'
config['metrics']      = ['auc', 'prc-auc']
config['metric']       = 'auc'
config['minimize_score'] = False
config['features_filename'] = 'features/tox21_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

config = {}
config['smiles_col'] = ['smiles']  #list
config['target_col'] = None #list
config['file_name'] = 'qm8.csv'
config['dataset_type'] = 'regression'
config['metrics']      = ['rmse', 'mae']
config['metric']       = 'rmse'
config['minimize_score'] = False
config['features_filename'] = 'features/qm8_features.npy'
config['savedir_name']  = config['file_name'].split('.')[0]
config_mod_list[config['file_name'].split('.')[0]] = config

# %%
config_mod_list
# Out:
# {'freesolv': {'smiles_col': ['smiles'],
#   'target_col': None,
#   'file_name': 'freesolv.csv',
#   'dataset_type': 'regression',
#   'metrics': ['rmse', 'mae'],
#   'metric': 'rmse',
#   'minimize_score': True,
#   'features_filename': 'features/freesolv_features.npy',
#   'savedir_name': 'freesolv'},
#  'delaney': {'smiles_col': ['smiles'],
#   'target_col': None,
#   'file_name': 'delaney.csv',
#   'dataset_type': 'regression',
#   'metrics': ['rmse', 'mae'],
#   'metric': 'rmse',
#   'minimize_score': True,
#   'features_filename': 'features/delaney_features.npy',
#   'savedir_name': 'delaney'},
#  'lipo': {'smiles_col': ['smiles'],
#   'target_col': ['lipo'],
#   'file_name': 'lipo.csv',
#   'dataset_type': 'regression',
#   'metrics': ['rmse', 'mae'],
#   'metric': 'rmse',
#   'minimize_score': True,
#   'features_filename': 'features/lipo_features.npy',
#   'savedir_name': 'lipo'},
#  'bace': {'smiles_col': ['mol'],
#   'target_col': ['Class'],
#   'file_name': 'bace.csv',
#   'dataset_type': 'classification',
#   'metrics': ['auc', 'prc-auc'],
#   'metric': 'auc',
#   'minimize_score': False,
#   'features_filename': 'features/bace_rdkit.npy',
#   'savedir_name': 'bace'},
#  'impensData_with_smiles': {'smiles_col': ['Peptide_smiles'],
#   'target_col': ['cleavage'],
#   'file_name': 'impensData_with_smiles.csv',
#   'dataset_type': 'classification',
#   'metrics': ['auc', 'prc-auc'],
#   'metric': 'auc',
#   'minimize_score': False,
#   'features_filename': 'features/impensData_features.npy',
#   'savedir_name': 'impensData_with_smiles'},
#  'bbbp_ch': {'smiles_col': ['smiles'],
#   'target_col': ['p_np'],
#   'file_name': 'bbbp_ch.csv',
#   'dataset_type': 'classification',
#   'metrics': ['auc', 'prc-auc'],
#   'metric': 'auc',
#   'minimize_score': False,
#   'features_filename': 'features/bbbp_features.npy',
#   'savedir_name': 'bbbp_ch'},
#  'tox21_ch': {'smiles_col': ['smiles'],
#   'target_col': None,
#   'file_name': 'tox21_ch.csv',
#   'dataset_type': 'classification',
#   'metrics': ['auc', 'prc-auc'],
#   'metric': 'auc',
#   'minimize_score': False,
#   'features_filename': 'features/tox21_features.npy',
#   'savedir_name': 'tox21_ch'},
#  'ecoli_inhibition': {'smiles_col': ['smiles'],
#   'target_col': None,
#   'file_name': 'ecoli_inhibition.csv',
#   'dataset_type': 'classification',
#   'metrics': ['auc', 'prc-auc'],
#   'metric': 'auc',
#   'minimize_score': False,
#   'features_filename': 'features/ecoli_inhibition_features.npy',
#   'savedir_name': 'ecoli_inhibition'},
#  '746Data_with_smiles': {'smiles_col': ['Peptide_smiles'],
#   'target_col': ['cleavage'],
#   'file_name': '746Data_with_smiles.csv',
#   'dataset_type': 'classification',
#   'metrics': ['auc', 'prc-auc'],
#   'metric': 'auc',
#   'minimize_score': False,
#   'features_filename': 'features/746Data_features.npy',
#   'savedir_name': '746Data_with_smiles'},
#  '1625Data_with_smiles': {'smiles_col': ['Peptide_smiles'],
#   'target_col': ['cleavage'],
#   'file_name': '1625Data_with_smiles.csv',
#   'dataset_type': 'classification',
#   'metrics': ['auc', 'prc-auc'],
#   'metric': 'auc',
#   'minimize_score': False,
#   'features_filename': 'features/1625Data_features.npy',
#   'savedir_name': '1625Data_with_smiles'},
#  'schillingData_with_smiles': {'smiles_col': ['Peptide_smiles'],
#   'target_col': ['cleavage'],
#   'file_name': 'schillingData_with_smiles.csv',
#   'dataset_type': 'classification',
#   'metrics': ['auc', 'prc-auc'],
#   'metric': 'auc',
#   'minimize_score': False,
#   'features_filename': 'features/schillingData_features.npy',
#   'savedir_name': 'schillingData_with_smiles'},
#  'mproxchem_ch': {'smiles_col': ['SMILES'],
#   'target_col': None,
#   'file_name': 'mproxchem_ch.csv',
#   'dataset_type': 'classification',
#   'metrics': ['auc', 'prc-auc'],
#   'metric': 'auc',
#   'minimize_score': False,
#   'features_filename': 'features/mproxchem_features.npy',
#   'savedir_name': 'mproxchem_ch'},
#  'clintox': {'smiles_col': ['smiles'],
#   'target_col': None,
#   'file_name': 'clintox.csv',
#   'dataset_type': 'classification',
#   'metrics': ['auc', 'prc-auc'],
#   'metric': 'auc',
#   'minimize_score': False,
#   'features_filename': 'features/clintox_features.npy',
#   'savedir_name': 'clintox'},
#  'sider': {'smiles_col': ['smiles'],
#   'target_col': None,
#   'file_name': 'sider.csv',
#   'dataset_type': 'classification',
#   'metrics': ['auc', 'prc-auc'],
#   'metric': 'auc',
#   'minimize_score': False,
#   'features_filename': 'features/sider_features.npy',
#   'savedir_name': 'sider'},
#  'qm8': {'smiles_col': ['smiles'],
#   'target_col': None,
#   'file_name': 'qm8.csv',
#   'dataset_type': 'regression',
#   'metrics': ['rmse', 'mae'],
#   'metric': 'rmse',
#   'minimize_score': False,
#   'features_filename': 'features/qm8_features.npy',
#   'savedir_name': 'qm8'}}

# %%
import pandas as pd
import os
data_sources = ['bace.csv', 'impensData_with_smiles.csv', 'bbbp_ch.csv', 'ecoli_inhibition.csv', 'mproxchem_ch.csv', '746Data_with_smiles.csv', '1625Data_with_smiles.csv', 'schillingData_with_smiles.csv', 'impensData_with_smiles.csv']
smiles = ['mol', 'Peptide_smiles', 'smiles', 'SMILES']
for i in data_sources:
    data = pd.read_csv(os.path.join('D:\Joe\Acads\Sem8\DDP\Code files\FSR\Data', i))
    target = config_mod_list[i.split('.')[0]]['target_col']
    columns = data.columns.values
    if target:
        target = target
    else:
        target = [col for col in columns if col not in smiles]
    output = data.loc[:,target[0]]
    ratio = len(output[output == output.unique()[0]])/len(output)
    print(round(ratio, 3) if ratio > 0.5 else round(1 - ratio,3))
# Out:
# 0.543
# 0.843
# 0.765
# 0.949
# 0.911
# 0.539
# 0.769
# 0.867
# 0.843
